# %%
import pandas as pd
import numpy as np
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD

# %%
df = pd.read_csv('../database/preprocessed_content_analysis.csv', index_col=0)
df
# Out:
#        first_name middle_name   last_name                               email  \
# 0           Talal         NaN        Asad             talalasad@earthlink.net
# 1           Talal         NaN        Asad             talalasad@earthlink.net
# 2           Talal         NaN        Asad             talalasad@earthlink.net
# 3           Talal         NaN        Asad             talalasad@earthlink.net
# 4            Leaf         NaN   Van Boven               vanboven@colorado.edu
# ...           ...         ...         ...                                 ...
# 115403    Francis           J  Magilligan  francis.j.magilligan@dartmouth.edu
# 115404    Francis           J  Magilligan  francis.j.magilligan@dartmouth.edu
# 115405    Francis           J  Magilligan  francis.j.magilligan@dartmouth.edu
# 115406    Francis           J  Magilligan  francis.j.magilligan@dartmouth.edu
# 115407    Francis           J  Magilligan  francis.j.magilligan@dartmouth.edu
#
#                                    institution  award_year  award_amount  \
# 0       cuny graduate school university center        2011         19901
# 1       cuny graduate school university center        2011         19901
# 2       cuny graduate school university center        2011         19901
# 3       cuny graduate school university center        2011         19901
# 4            university of colorado at boulder        2011        250000
# ...                                        ...         ...           ...
# 115403                       dartmouth college        2020        427479
# 115404                       dartmouth college        2020        427479
# 115405                       dartmouth college        2020        427479
# 115406                       dartmouth college        2020        427479
# 115407                       dartmouth college        2020        427479
#
#                                               paper_title  \
# 0       Effect of oxidation and geometrical dimensions...
# 1       Synthesis and biological evaluation of new pyr...
# 2       Synthesis of 6-Ethyl-1, 2, 9-trioxopyrrolo [3,...
# 3       Randa M. Al-As’ ada, Mustafa M. El-abadelaha, ...
# 4       Identifiable but not identical: Combining soci...
# ...                                                   ...
# 115403  Assessing the Impacts of Extreme Precipitation...
# 115404  What is Fluvial Geomorphic Equilibrium?: Evalu...
# 115405  Bankfull Channel Adjustments to Episodic and L...
# 115406  Elevated post-event sediment yield extends the...
# 115407  Connectivity in geomorphology. Proceedings of ...
#
#                                  journal  publication_year  ... citation_2019  \
# 0                           Desalination              2011  ...            13
# 1                              Molecules              2014  ...            13
# 2       Zeitschrift für Naturforschung B              2013  ...            13
# 3                         Z. Naturforsch              2013  ...            13
# 4           Journal of Consumer research              2012  ...           868
# ...                                  ...               ...  ...           ...
# 115403        AGU Fall Meeting Abstracts              2020  ...           453
# 115404        AGU Fall Meeting Abstracts              2019  ...           453
# 115405        AGU Fall Meeting Abstracts              2019  ...           453
# 115406        AGU Fall Meeting Abstracts              2018  ...           453
# 115407                     Geomorphology              2017  ...           453
#
#        citation_2020  citation_2021  citation_2022  citation_2023  \
# 0                  5             10              5              7
# 1                  5             10              5              7
# 2                  5             10              5              7
# 3                  5             10              5              7
# 4               1234           1132           1198           1222
# ...              ...            ...            ...            ...
# 115403           500            457            549            582
# 115404           500            457            549            582
# 115405           500            457            549            582
# 115406           500            457            549            582
# 115407           500            457            549            582
#
#         citation_2024                                    tokenized_title  \
# 0                   1  ['Effect', 'of', 'oxidation', 'and', 'geometri...
# 1                   1  ['Synthesis', 'and', 'biological', 'evaluation...
# 2                   1  ['Synthesis', 'of', '6', 'Ethyl-1', '2', '9', ...
# 3                   1  ['Randa', 'M.', 'Al', 'As', 'ada', 'Mustafa', ...
# 4                 179  ['Identifiable', 'but', 'not', 'identical', 'C...
# ...               ...                                                ...
# 115403            101  ['Assessing', 'the', 'Impacts', 'of', 'Extreme...
# 115404            101  ['What', 'is', 'Fluvial', 'Geomorphic', 'Equil...
# 115405            101  ['Bankfull', 'Channel', 'Adjustments', 'to', '...
# 115406            101  ['Elevated', 'post', 'event', 'sediment', 'yie...
# 115407            101  ['Connectivity', 'in', 'geomorphology', 'Proce...
#
#                                          normalized_title  \
# 0       ['effect', 'oxidation', 'geometrical', 'dimens...
# 1       ['synthesis', 'biological', 'evaluation', 'new...
# 2       ['synthesis', 'ethyl-1', 'trioxopyrrolo', 'f',...
# 3       ['randa', 'm.', 'al', 'ada', 'mustafa', 'm.', ...
# 4       ['identifiable', 'identical', 'combine', 'soci...
# ...                                                   ...
# 115403  ['assess', 'impact', 'extreme', 'precipitation...
# 115404  ['fluvial', 'geomorphic', 'equilibrium', 'eval...
# 115405  ['bankfull', 'channel', 'adjustment', 'episodi...
# 115406  ['elevate', 'post', 'event', 'sediment', 'yiel...
# 115407  ['connectivity', 'geomorphology', 'proceeding'...
#
#                                        tokenized_abstract  \
# 0       ['This', 'study', 'reports', 'for', 'the', 'fi...
# 1       ['A', 'selected', 'set', 'of', 'substituted', ...
# 2       ['Interaction', 'of', '6', 'amino-1', 'ethyl-4...
# 3       ['Interaction', 'of', '6', 'amino-1', 'ethyl-4...
# 4       ['How', 'do', 'consumers', 'reconcile', 'confl...
# ...                                                   ...
# 115403  ['Floods', 'have', 'a', 'devastating', 'impact...
# 115404  ['Various', 'definitions', 'of', 'equilibrium'...
# 115405  ['The', 'bankfull', 'Shields', 'value', 'is', ...
# 115406  ['The', 'long', 'term', 'effects', 'of', 'cata...
# 115407  ['With', 'the', 'increased', 'recent', 'attent...
#
#                                       normalized_abstract
# 0       ['study', 'report', 'time', 'use', 'oxidize', ...
# 1       ['select', 'set', 'substituted', 'pyridone', '...
# 2       ['interaction', 'amino-1', 'ethyl-4', 'oxoquin...
# 3       ['interaction', 'amino-1', 'ethyl-4', 'oxoquin...
# 4       ['consumer', 'reconcile', 'conflicting', 'moti...
# ...                                                   ...
# 115403  ['flood', 'devastating', 'impact', 'infrastruc...
# 115404  ['definition', 'equilibrium', 'alluvial', 'cha...
# 115405  ['bankfull', 'shield', 'value', 'increasingly'...
# 115406  ['long', 'term', 'effect', 'catastrophic', 'fl...
# 115407  ['increase', 'recent', 'attention', 'understan...
#
# [115408 rows x 41 columns]

# %%
# prepare data for cluatering
df['normalized_abstract'] = df['normalized_abstract'].apply(ast.literal_eval)
df['normalized_abstract'] = df['normalized_abstract'].apply(lambda x: ' '.join(x))

# %%
# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=1000)

# generate TF-IDF matrix
tfidf_matrix = tfidf_vectorizer.fit_transform(df['normalized_abstract'])

# %%
# fit SVD
n_components = min(tfidf_matrix.shape) - 1
svd = TruncatedSVD(n_components=n_components)
svd.fit(tfidf_matrix)

# calculate the cumulative explained variance ratio
cumulative_explained_variance = np.cumsum(svd.explained_variance_ratio_)

# calculate the number of SVD components capturing 95% variance 
num_components = np.argmax(cumulative_explained_variance >= 0.95) + 1
num_components
# Out:
# 871

# %%
# fit and transform TF-IDF matrix
svd = TruncatedSVD(n_components=871)
tfidf_matrix_reduced = svd.fit_transform(tfidf_matrix)

# %%
num_clusters = range(1, 21)

# calculate the inertia for each number of clusters
inertias = []
for k in num_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(tfidf_matrix_reduced)
    inertias.append(kmeans.inertia_)

# Plot the elbow plot
plt.figure(figsize=(12, 6))
plt.plot(num_clusters, inertias, marker='o', linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Plot for K-Means Clustering')
plt.xticks(num_clusters)
plt.show()

# %%
# perform K-means clustering on TF-IDF matrix
kmeans_tfidf = KMeans(n_clusters=5, random_state=42)
kmeans_tfidf.fit(tfidf_matrix_reduced)

# add cluster labels to the dataframe
df['tfidf_cluster'] = kmeans_tfidf.labels_

# %%
# Word2Vec Vectorization
word2vec_model = Word2Vec(sentences=df['normalized_abstract'].sum(), vector_size=300, window=5, min_count=10, sg=1)

def vectorize(abstract, model):
    vector = np.mean([model.wv[word] for word in abstract if word in model.wv] or [np.zeros(model.vector_size)], axis=0)
    return vector

# generate Word2Vec vectors
w2v_vectors = np.vstack(df['normalized_abstract'].apply(lambda x: vectorize(x, word2vec_model)))

# %%
# fit PCA
pca = PCA().fit(w2v_vectors)

# calculate the cumulative explained variance ratio
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# calculate the number of PCA components capturing 95% variance 
num_components = np.argmax(cumulative_explained_variance >= 0.95) + 1
num_components
# Out:
# 21

# %%
# fit and transform Word2Vec vectors
pca = PCA(n_components=21)
w2v_vectors_reduced = pca.fit_transform(w2v_vectors)

# %%
num_clusters = range(1, 21)

# calculate the inertia for each number of clusters
inertias = []
for k in num_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(w2v_vectors_reduced)
    inertias.append(kmeans.inertia_)

# Plot the elbow plot
plt.figure(figsize=(12, 6))
plt.plot(num_clusters, inertias, marker='o', linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Plot for K-Means Clustering')
plt.xticks(num_clusters)
plt.show()

# %%
# perform K-means clustering on Word2Vec vectors
kmeans_w2v = KMeans(n_clusters=5, random_state=42)
kmeans_w2v.fit(w2v_vectors_reduced)

# add cluster labels to the dataframe
df['w2v_cluster'] = kmeans_w2v.labels_

# %%
# function to find the most distinctive words in each cluster
def find_distinctive_words_by_cluster(clusters):
    aggregate_tfidf_vectors_by_cluster = {}
    
    for i, cluster in enumerate(clusters):
        if cluster not in aggregate_tfidf_vectors_by_cluster:
            aggregate_tfidf_vectors_by_cluster[cluster] = tfidf_matrix[i]
        else:
            aggregate_tfidf_vectors_by_cluster[cluster] += tfidf_matrix[i]

    distinctive_words_by_cluster = {}
    feature_names = np.array(tfidf_vectorizer.get_feature_names_out())
    
    for cluster, agg_tfidf in aggregate_tfidf_vectors_by_cluster.items():
        sorted_indices = np.argsort(agg_tfidf.toarray()).flatten()[::-1]
        distinctive_words_by_cluster[cluster] = feature_names[sorted_indices][:20]

    for cluster, words in distinctive_words_by_cluster.items():
        print(f"Cluster {cluster}: {words}")

# %%
# find the most distinctive words in each TF-IDF cluster
find_distinctive_words_by_cluster(df['tfidf_cluster'])
# Out:
# Cluster 1: ['social' 'study' 'human' 'research' 'datum' 'group' 'health' 'individual'
#  'population' 'analysis' 'model' 'child' 'high' 'people' 'new' 'behavior'
#  'examine' 'include' 'system' 'development']
# Cluster 4: ['task' 'memory' 'visual' 'object' 'model' 'word' 'brain' 'experiment'
#  'study' 'information' 'participant' 'speech' 'neural' 'stimulus' 'learn'
#  'effect' 'child' 'processing' 'control' 'response']
# Cluster 0: ['language' 'linguistic' 'english' 'speaker' 'word' 'bilingual' 'sign'
#  'l2' 'speech' 'child' 'spanish' 'study' 'speak' 'native' 'learner'
#  'acquisition' 'use' 'research' 'processing' 'learn']
# Cluster 3: ['site' 'climate' 'change' 'date' 'region' 'water' 'archaeological'
#  'record' 'datum' 'early' 'period' 'land' 'forest' 'year' 'area' 'human'
#  'late' 'analysis' 'large' 'sediment']
# Cluster 2: ['de' 'la' 'en' 'que' 'el' 'los' 'las' 'se' 'del' 'et' 'al' 'social'
#  'maya' 'site' 'question' 'regional' 'base' 'cultural' 'article' 'central']

# %%
# create a new mapping dictionary for each TF-IDF cluster
tfidf_cluster_mapping = {
    0: 'Linguistics',
    1: 'Psychology',
    2: 'Spanish Studies',
    3: 'Environmental Studies',
    4: 'Cognitive Science'
}

# apply the new mapping to the TF-IDF cluster labels
df['tfidf_cluster'] = df['tfidf_cluster'].map(tfidf_cluster_mapping)

# %%
# find the most distinctive words in each Word2Vec cluster
find_distinctive_words_by_cluster(df['w2v_cluster'])
# Out:
# Cluster 2: ['study' 'language' 'human' 'social' 'individual' 'information' 'change'
#  'model' 'brain' 'result' 'network' 'population' 'datum' 'analysis' 'task'
#  'attention' 'high' 'effect' 'examine' 'region']
# Cluster 0: ['social' 'study' 'human' 'model' 'research' 'datum' 'group' 'provide'
#  'change' 'process' 'population' 'food' 'analysis' 'child' 'work' 'high'
#  'new' 'approach' 'include' 'system']
# Cluster 4: ['language' 'study' 'child' 'model' 'research' 'effect' 'change'
#  'experience' 'human' 'speech' 'experiment' 'word' 'use' 'result' 'time'
#  'present' 'people' 'evidence' 'system' 'level']
# Cluster 3: ['study' 'datum' 'research' 'result' 'model' 'system' 'time' 'base' 'task'
#  'effect' 'present' 'participant' 'use' 'test' 'measure' 'response'
#  'analysis' 'target' 'high' 'visual']
# Cluster 1: ['language' 'de' 'human' 'datum' 'change' 'study' 'analysis' 'site' 'age'
#  'year' 'early' 'model' 'large' 'child' 'area' 'la' 'high' 'new' 'use'
#  'region']

# %%
# # create a new mapping dictionary for each Word2Vec cluster
w2v_cluster_mapping = {
    0: 'Social Psychology',
    1: 'Archaeology',
    2: 'Cognitive Science',
    3: 'Experimental Studies',
    4: 'Linguistics'
}

# apply the new mapping to the Word2Vec cluster labels
df['w2v_cluster'] = df['w2v_cluster'].map(w2v_cluster_mapping)

# %%
cluster_df = df[['email', 'tfidf_cluster', 'w2v_cluster']]
cluster_df
# Out:
#                                      email          tfidf_cluster  \
# 0                  talalasad@earthlink.net             Psychology
# 1                  talalasad@earthlink.net             Psychology
# 2                  talalasad@earthlink.net             Psychology
# 3                  talalasad@earthlink.net             Psychology
# 4                    vanboven@colorado.edu             Psychology
# ...                                    ...                    ...
# 115403  francis.j.magilligan@dartmouth.edu  Environmental Studies
# 115404  francis.j.magilligan@dartmouth.edu             Psychology
# 115405  francis.j.magilligan@dartmouth.edu  Environmental Studies
# 115406  francis.j.magilligan@dartmouth.edu  Environmental Studies
# 115407  francis.j.magilligan@dartmouth.edu             Psychology
#
#                  w2v_cluster
# 0          Cognitive Science
# 1          Social Psychology
# 2          Social Psychology
# 3          Social Psychology
# 4          Cognitive Science
# ...                      ...
# 115403  Experimental Studies
# 115404     Social Psychology
# 115405           Archaeology
# 115406     Social Psychology
# 115407     Cognitive Science
#
# [115408 rows x 3 columns]

# %%
cluster_df.to_csv('cluster_by_paper.csv')

# %%
# pandas and visualization libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# statsmodels
import statsmodels.api as sm

# %%
df = pd.read_stata('reg_data.dta')
df
# Out:
#                       email  year                institution  \
# 0      00t0holtgrav@bsu.edu  2011      Ball State University
# 1      00t0holtgrav@bsu.edu  2012      Ball State University
# 2      00t0holtgrav@bsu.edu  2013      Ball State University
# 3      00t0holtgrav@bsu.edu  2014      Ball State University
# 4      00t0holtgrav@bsu.edu  2015      Ball State University
# ...                     ...   ...                        ...
# 20635          zulu@msu.edu  2016  Michigan State University
# 20636          zulu@msu.edu  2017  Michigan State University
# 20637          zulu@msu.edu  2018  Michigan State University
# 20638          zulu@msu.edu  2019  Michigan State University
# 20639          zulu@msu.edu  2020  Michigan State University
#
#                                                interests  award_year  \
# 0                     ['Social Psychology and Language']        2012
# 1                     ['Social Psychology and Language']        2012
# 2                     ['Social Psychology and Language']        2012
# 3                     ['Social Psychology and Language']        2012
# 4                     ['Social Psychology and Language']        2012
# ...                                                  ...         ...
# 20635  ['Environment/Society - natural resources gove...        2014
# 20636  ['Environment/Society - natural resources gove...        2014
# 20637  ['Environment/Society - natural resources gove...        2014
# 20638  ['Environment/Society - natural resources gove...        2014
# 20639  ['Environment/Society - natural resources gove...        2014
#
#        expiration_year  award_amount  \
# 0                 2017             0
# 1                 2017        165000
# 2                 2017        165000
# 3                 2017        165000
# 4                 2017        165000
# ...                ...           ...
# 20635             2015             0
# 20636             2015             0
# 20637             2015             0
# 20638             2015             0
# 20639             2015             0
#
#                                              award_title  total_citations  \
# 0      The Role of Interpersonal Processes in the Int...            10066
# 1      The Role of Interpersonal Processes in the Int...            10066
# 2      The Role of Interpersonal Processes in the Int...            10066
# 3      The Role of Interpersonal Processes in the Int...            10066
# 4      The Role of Interpersonal Processes in the Int...            10066
# ...                                                  ...              ...
# 20635  Doctoral Dissertation Research: Decentralizati...             1930
# 20636  Doctoral Dissertation Research: Decentralizati...             1930
# 20637  Doctoral Dissertation Research: Decentralizati...             1930
# 20638  Doctoral Dissertation Research: Decentralizati...             1930
# 20639  Doctoral Dissertation Research: Decentralizati...             1930
#
#        h_index  citation  pub_num   top_cited
# 0           46     367.0        2  135.000000
# 1           46     409.0        4   14.666667
# 2           46     534.0        7  281.666656
# 3           46     550.0        8   32.333332
# 4           46     496.0        3   14.000000
# ...        ...       ...      ...         ...
# 20635       21     117.0        9   29.333334
# 20636       21     151.0        8    5.666667
# 20637       21     165.0        9   39.333332
# 20638       21     177.0        0    0.000000
# 20639       21     194.0        5   23.666666
#
# [20640 rows x 13 columns]

# %%
# Filter out data where award_amount is 0
filtered_df = df[df['award_amount'] > 0]

# Use the filtered data to plot a histogram
sns.histplot(data=filtered_df, x="award_amount")

# Add vertical lines for the mean, median, and mode on the histogram
plt.axvline(x=filtered_df['award_amount'].mean(), color='blue', label='Mean')
plt.axvline(x=filtered_df['award_amount'].median(), color='red', label='Median')
plt.axvline(x=filtered_df['award_amount'].mode().values[0], color='orange', label='Mode') # Mode

# %%
for column in ['pub_num', 'top_cited']:
    mean = filtered_df[column].mean()
    std = filtered_df[column].std()
    # Define the range for outliers
    lower_limit = mean - 3 * std
    upper_limit = mean + 3 * std
    # Keep only the data within (mean - 3*SD, mean + 3*SD) range
    filtered_df = filtered_df[(filtered_df[column] >= lower_limit) & (filtered_df[column] <= upper_limit)]

sns.jointplot(x = "award_amount", y = "pub_num", data = filtered_df, height = 5)

# %%
sns.jointplot(x = "award_amount", y = "top_cited", data = filtered_df, height = 5)

# %%
sns.lmplot(data = filtered_df, x = 'award_amount', y = 'pub_num', height = 4, aspect = 1)
plt.title('publication number by awarded amount', size = 12)
plt.xlabel('award_amount ($)', size = 10)
plt.ylabel('publication number', size = 10)
# Out:
# Text(33.51562500000001, 0.5, 'publication number')

# %%
sns.lmplot(data = filtered_df, x = 'award_amount', y = 'top_cited', height = 4, aspect = 1)
plt.title('cited number by awarded amount', size = 12)
plt.xlabel('award_amount ($)', size = 10)
plt.ylabel('cited number', size = 10)
# Out:
# Text(24.640625000000007, 0.5, 'cited number')

# %%
# Get the summary statistics
summary_statistics = df.describe()
print(summary_statistics)
# Out:
#                year    award_year  expiration_year  award_amount  \
# count  20640.000000  20640.000000     20640.000000  2.064000e+04
# mean    2015.500000   2014.872093      2018.179264  1.304730e+05
# std        2.872351      2.660993         3.304241  2.703923e+05
# min     2011.000000   2011.000000      2011.000000  0.000000e+00
# 25%     2013.000000   2012.000000      2015.000000  0.000000e+00
# 50%     2015.500000   2015.000000      2018.000000  0.000000e+00
# 75%     2018.000000   2017.000000      2021.000000  1.600000e+05
# max     2020.000000   2020.000000      2026.000000  3.236042e+06
#
#        total_citations       h_index      citation       pub_num     top_cited
# count     20640.000000  20640.000000  20113.000000  20640.000000  20004.000000
# mean       8797.634205     33.613372    476.106200      5.471512     84.653544
# std       17447.221015     22.731402    965.345139     10.208911    305.649815
# min           1.000000      1.000000      1.000000      0.000000      0.000000
# 25%        1591.500000     18.000000     81.000000      2.000000      9.000000
# 50%        3902.500000     29.000000    210.000000      4.000000     33.000000
# 75%        9430.750000     43.000000    511.000000      7.000000     82.666667
# max      361975.000000    192.000000  24631.000000   1129.000000  22244.000000

# %%
# Setting variables for the regression
Y1 = df['pub_num']
X1 = df[['award_amount', 'citation', 'h_index']]
X1 = X1.replace([np.inf, -np.inf], np.nan)  
X1 = X1.dropna()  
Y1 = Y1[X1.index]  
# Adding a constant to the model
X_const = sm.add_constant(X1)

# Fitting the OLS model
ols_m = sm.OLS(Y1, X_const).fit()
print(ols_m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                pub_num   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     985.0
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:26:23   Log-Likelihood:                -74084.
# No. Observations:               20113   AIC:                         1.482e+05
# Df Residuals:                   20109   BIC:                         1.482e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2490      0.141      1.771      0.077      -0.027       0.525
# award_amount   1.83e-06   2.51e-07      7.301      0.000    1.34e-06    2.32e-06
# citation         0.0005      0.000      5.137      0.000       0.000       0.001
# h_index          0.1415      0.004     31.490      0.000       0.133       0.150
# ==============================================================================
# Omnibus:                    74582.951   Durbin-Watson:                   1.434
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      72701873605.451
# Skew:                          80.464   Prob(JB):                         0.00
# Kurtosis:                    9315.690   Cond. No.                     6.28e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.28e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Setting variables for the regression
Y2 = df['top_cited']
X = df[['award_amount', 'citation', 'h_index']]
Y2 = Y2.replace(np.nan, 0)
X = X.replace([np.inf, -np.inf], np.nan)  
X = X.dropna()  
Y2 = Y2[X.index]  
# Adding a constant to the model
X_const = sm.add_constant(X)

# Fitting the OLS model
ols_m2 = sm.OLS(Y2, X_const).fit()
print(ols_m2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              top_cited   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     895.3
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:26:28   Log-Likelihood:            -1.4232e+05
# No. Observations:               20113   AIC:                         2.847e+05
# Df Residuals:                   20109   BIC:                         2.847e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           26.6136      4.183      6.363      0.000      18.415      34.812
# award_amount -1.872e-05   7.46e-06     -2.511      0.012   -3.33e-05   -4.11e-06
# citation         0.1032      0.003     33.071      0.000       0.097       0.109
# h_index          0.3095      0.134      2.315      0.021       0.047       0.571
# ==============================================================================
# Omnibus:                    56111.926   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4031731859.812
# Skew:                          35.854   Prob(JB):                         0.00
# Kurtosis:                    2195.203   Cond. No.                     6.28e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.28e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df['dummy_award'] = (df['award_amount'] != 0).astype(int)

# Setting variables for the regression
Y3 = df['pub_num']
X3 = df[['dummy_award', 'citation', 'h_index']]
X3 = X3.replace([np.inf, -np.inf], np.nan)  
X3 = X3.dropna()  
Y3 = Y3[X.index]  
# Adding a constant to the model
X_const = sm.add_constant(X3)

# Fitting the OLS model
ols_m3 = sm.OLS(Y3, X_const).fit()
print(ols_m3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                pub_num   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     988.8
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:26:47   Log-Likelihood:                -74079.
# No. Observations:               20113   AIC:                         1.482e+05
# Df Residuals:                   20109   BIC:                         1.482e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0590      0.151     -0.392      0.695      -0.355       0.236
# dummy_award     1.0859      0.137      7.954      0.000       0.818       1.353
# citation        0.0005      0.000      4.979      0.000       0.000       0.001
# h_index         0.1435      0.004     32.040      0.000       0.135       0.152
# ==============================================================================
# Omnibus:                    74551.755   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      72443060201.146
# Skew:                          80.360   Prob(JB):                         0.00
# Kurtosis:                    9299.098   Cond. No.                     2.70e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Setting variables for the regression
Y4 = df['top_cited']
Y4 = Y4.replace(np.nan, 0)
X4 = df[['dummy_award', 'citation', 'h_index']]
X4 = X4.replace([np.inf, -np.inf], np.nan)  
X4 = X4.dropna()  
Y4 = Y4[X.index]  
# Adding a constant to the model
X_const = sm.add_constant(X4)

# Fitting the OLS model
ols_m4 = sm.OLS(Y4, X_const).fit()
print(ols_m4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              top_cited   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     901.7
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:27:21   Log-Likelihood:            -1.4232e+05
# No. Observations:               20113   AIC:                         2.846e+05
# Df Residuals:                   20109   BIC:                         2.847e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          33.4035      4.484      7.450      0.000      24.615      42.192
# dummy_award   -19.5815      4.061     -4.822      0.000     -27.541     -11.622
# citation        0.1035      0.003     33.171      0.000       0.097       0.110
# h_index         0.2924      0.133      2.194      0.028       0.031       0.554
# ==============================================================================
# Omnibus:                    56121.772   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4041959385.566
# Skew:                          35.870   Prob(JB):                         0.00
# Kurtosis:                    2197.984   Cond. No.                     2.70e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create dummy variables for the year, set drop_first=True to avoid multicollinearity
year_dummies = pd.get_dummies(df['year'], prefix='d', drop_first=False)

# Select nine dummy variables that do not include 2020
year_dummies = year_dummies.iloc[:, :-1]  # Assuming the last column is d2020

# Set dependent variable Y5 and independent variables X5
Y5 = df['pub_num']
X5 = df[['award_amount', 'citation', 'h_index']]

# Check and handle NaN values
X5 = X5.replace([np.inf, -np.inf], np.nan).dropna()
Y5 = Y5[X5.index]

# Add the dummy variables to X5
X5 = pd.concat([X5, year_dummies.loc[X5.index]], axis=1)

# Add a constant to X5 to fit the intercept
X5_const = sm.add_constant(X5)

# Fit the OLS model
ols_m5 = sm.OLS(Y5, X5_const).fit()

# Print the model summary
print(ols_m5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                pub_num   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     248.4
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:27:52   Log-Likelihood:                -74073.
# No. Observations:               20113   AIC:                         1.482e+05
# Df Residuals:                   20100   BIC:                         1.483e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0488      0.243      0.201      0.841      -0.427       0.525
# award_amount  1.906e-06   2.58e-07      7.401      0.000     1.4e-06    2.41e-06
# citation         0.0006      0.000      5.281      0.000       0.000       0.001
# h_index          0.1406      0.005     30.900      0.000       0.132       0.150
# d_2011          -0.0428      0.312     -0.137      0.891      -0.654       0.569
# d_2012           0.0979      0.308      0.318      0.751      -0.506       0.702
# d_2013           1.0533      0.306      3.447      0.001       0.454       1.652
# d_2014           0.4448      0.304      1.464      0.143      -0.151       1.040
# d_2015           0.3829      0.303      1.266      0.206      -0.210       0.976
# d_2016          -0.0449      0.302     -0.149      0.882      -0.636       0.547
# d_2017          -0.0814      0.301     -0.270      0.787      -0.672       0.509
# d_2018           0.2237      0.301      0.743      0.458      -0.367       0.814
# d_2019           0.0616      0.301      0.205      0.838      -0.528       0.652
# ==============================================================================
# Omnibus:                    74571.374   Durbin-Watson:                   1.434
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      72605617462.536
# Skew:                          80.425   Prob(JB):                         0.00
# Kurtosis:                    9309.523   Cond. No.                     3.16e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.16e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create dummy variables for the year, set drop_first=True to avoid multicollinearity
year_dummies = pd.get_dummies(df['year'], prefix='d', drop_first=False)

# Select nine dummy variables that do not include 2020
year_dummies = year_dummies.iloc[:, :-1]  # Assuming the last column is d2020

# Set dependent variable Y6 and independent variables X6
Y6 = df['top_cited']
X6 = df[['award_amount', 'citation', 'h_index']]
Y6 = Y6.replace(np.nan, 0)
# Check and handle NaN values
X6 = X6.replace([np.inf, -np.inf], np.nan).dropna()
Y6 = Y6[X6.index]

# Add the dummy variables to X6
X6 = pd.concat([X6, year_dummies.loc[X6.index]], axis=1)

# Add a constant to X6 to fit the intercept
X6_const = sm.add_constant(X6)

# Fit the OLS model
ols_m6 = sm.OLS(Y6, X6_const).fit()

# Print the model summary
print(ols_m6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              top_cited   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     256.1
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:32:37   Log-Likelihood:            -1.4215e+05
# No. Observations:               20113   AIC:                         2.843e+05
# Df Residuals:                   20100   BIC:                         2.844e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -19.0129      7.173     -2.651      0.008     -33.073      -4.953
# award_amount  1.188e-05    7.6e-06      1.562      0.118   -3.02e-06    2.68e-05
# citation         0.1131      0.003     35.953      0.000       0.107       0.119
# h_index         -0.0697      0.134     -0.519      0.604      -0.333       0.194
# d_2011          99.2072      9.207     10.775      0.000      81.161     117.253
# d_2012         102.4879      9.092     11.273      0.000      84.667     120.309
# d_2013          82.4828      9.019      9.145      0.000      64.805     100.161
# d_2014          79.5504      8.968      8.870      0.000      61.972      97.129
# d_2015          68.5166      8.931      7.672      0.000      51.012      86.022
# d_2016          25.1855      8.907      2.828      0.005       7.726      42.645
# d_2017          36.2541      8.897      4.075      0.000      18.814      53.694
# d_2018          16.1426      8.891      1.816      0.069      -1.285      33.570
# d_2019          -4.8425      8.885     -0.545      0.586     -22.257      12.572
# ==============================================================================
# Omnibus:                    56398.459   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4217240681.137
# Skew:                          36.342   Prob(JB):                         0.00
# Kurtosis:                    2245.091   Cond. No.                     3.16e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.16e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create dummy variables for the year, set drop_first=True to avoid multicollinearity
year_dummies = pd.get_dummies(df['year'], prefix='d', drop_first=False)

# Select nine dummy variables that do not include 2020
year_dummies = year_dummies.iloc[:, :-1]  # Assuming the last column is d2020

# Set dependent variable Y7 and independent variables X7
Y7 = df['pub_num']
X7 = df[['dummy_award', 'citation', 'h_index']]

# Check and handle NaN values
X7 = X7.replace([np.inf, -np.inf], np.nan).dropna()
Y7 = Y7[X7.index]

# Add the dummy variables to X7
X7 = pd.concat([X7, year_dummies.loc[X7.index]], axis=1)

# Add a constant to X5 to fit the intercept
X7_const = sm.add_constant(X7)

# Fit the OLS model
ols_m7 = sm.OLS(Y7, X7_const).fit()

# Print the model summary
print(ols_m7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                pub_num   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     249.1
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:33:56   Log-Likelihood:                -74069.
# No. Observations:               20113   AIC:                         1.482e+05
# Df Residuals:                   20100   BIC:                         1.483e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.2403      0.250     -0.961      0.337      -0.731       0.250
# dummy_award     1.1355      0.143      7.929      0.000       0.855       1.416
# citation        0.0006      0.000      5.212      0.000       0.000       0.001
# h_index         0.1424      0.005     31.439      0.000       0.133       0.151
# d_2011          0.1067      0.315      0.339      0.734      -0.510       0.723
# d_2012          0.1339      0.308      0.434      0.664      -0.470       0.738
# d_2013          1.0126      0.305      3.321      0.001       0.415       1.610
# d_2014          0.3702      0.303      1.221      0.222      -0.224       0.964
# d_2015          0.2938      0.302      0.972      0.331      -0.298       0.886
# d_2016         -0.1161      0.302     -0.385      0.700      -0.707       0.475
# d_2017         -0.1504      0.301     -0.499      0.618      -0.741       0.440
# d_2018          0.1689      0.301      0.561      0.575      -0.422       0.759
# d_2019          0.0244      0.301      0.081      0.935      -0.566       0.614
# ==============================================================================
# Omnibus:                    74535.472   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      72308726822.343
# Skew:                          80.307   Prob(JB):                         0.00
# Kurtosis:                    9290.474   Cond. No.                     1.12e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create dummy variables for the year, set drop_first=True to avoid multicollinearity
year_dummies = pd.get_dummies(df['year'], prefix='d', drop_first=False)

# Select nine dummy variables that do not include 2020
year_dummies = year_dummies.iloc[:, :-1]  # Assuming the last column is d2020

# Set dependent variable Y8 and independent variables X8
Y8 = df['top_cited']
Y8 = Y8.replace(np.nan, 0)
X8 = df[['dummy_award', 'citation', 'h_index']]

# Check and handle NaN values
X8 = X8.replace([np.inf, -np.inf], np.nan).dropna()
Y8 = Y8[X8.index]

# Add the dummy variables to X7
X8 = pd.concat([X8, year_dummies.loc[X8.index]], axis=1)

# Add a constant to X5 to fit the intercept
X8_const = sm.add_constant(X8)

# Fit the OLS model
ols_m8 = sm.OLS(Y8, X8_const).fit()

# Print the model summary
print(ols_m8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              top_cited   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     255.9
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:35:16   Log-Likelihood:            -1.4216e+05
# No. Observations:               20113   AIC:                         2.843e+05
# Df Residuals:                   20100   BIC:                         2.844e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -16.7421      7.387     -2.266      0.023     -31.221      -2.263
# dummy_award    -1.3450      4.228     -0.318      0.750      -9.632       6.942
# citation        0.1129      0.003     35.889      0.000       0.107       0.119
# h_index        -0.0444      0.134     -0.332      0.740      -0.306       0.218
# d_2011         96.4481      9.289     10.383      0.000      78.241     114.655
# d_2012        100.3810      9.100     11.031      0.000      82.544     118.218
# d_2013         80.8626      9.001      8.984      0.000      63.220      98.505
# d_2014         78.4160      8.951      8.761      0.000      60.871      95.961
# d_2015         67.8157      8.921      7.602      0.000      50.330      85.302
# d_2016         24.7994      8.904      2.785      0.005       7.346      42.253
# d_2017         36.1084      8.898      4.058      0.000      18.667      53.550
# d_2018         16.2061      8.894      1.822      0.068      -1.227      33.639
# d_2019         -4.6372      8.887     -0.522      0.602     -22.057      12.783
# ==============================================================================
# Omnibus:                    56401.429   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4220869698.425
# Skew:                          36.346   Prob(JB):                         0.00
# Kurtosis:                    2246.057   Cond. No.                     1.12e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
